# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
track = 6

data_path = '../../Data/Plotting/AccTrack' + str(track) + '.csv'

df = pd.read_csv(data_path, header=None)

# %%
plt.figure()
plt.plot(df[0], df[1])
plt.show()
